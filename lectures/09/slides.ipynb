# %% [markdown]
# # Quiz 1
#
# CSI 4506 - automne 2026
#
# Marcel Turcotte
# Version: août 9, 2026 12h07
#
# ## CSI 4506

# %% [raw]
# <style>
#   #clock {
#     color: #007bff; /* Example color */
#     /* Add any other styling here */
#   }
# </style>

# %% [raw]
# <script>
#   function updateClock() {
#     const now = new Date();
#     let hours = now.getHours();
#     let minutes = now.getMinutes();
#     let seconds = now.getSeconds();
#
#     // Add leading zeros if needed
#     hours = hours < 10 ? '0' + hours : hours;
#     minutes = minutes < 10 ? '0' + minutes : minutes;
#     seconds = seconds < 10 ? '0' + seconds : seconds;
#
#     const timeString = hours + ':' + minutes + ':' + seconds;
#
#     document.getElementById('clock').textContent = timeString;
#   }
#
#   // Update the clock immediately and then every second
#   document.addEventListener('DOMContentLoaded', (event) => {
#     updateClock();
#     setInterval(updateClock, 1000);
#   });
# </script>

# %% [markdown]
# 1.  **Attendez** le signal pour commencer.
# 2.  Écrivez votre **nom** et **numéro d’étudiant** sur le
#     **questionnaire** et le **Scantron**.
# 3.  Si terminé, **levez la main** pour soumettre et partir.
# 4.  **Restez assis** si plusieurs finissent en même temps.
# 5.  Remettez toutes les copies **10 min avant le prochain cours**.
